# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import sys
import numpy

# %%
url = "https://www.pcfactory.cl/notebooks?categoria=735&papa=636"
url2 = "https://www.pcfactory.cl/notebooks?categoria=735&papa=636&pagina=2"

# %%
response = requests.get(url)
response2 = requests.get(url2)

# %%
data = response.text
data2 = response2.text

# %%
soup = BeautifulSoup(data,"html.parser")
soup2 = BeautifulSoup(data2,"html.parser")

# %%
bloque = soup.find_all("div",{"class":"product"})
bloque2 = soup2.find_all("div",{"class":"product"})

# %%
links_with_text = []
for i in bloque:
    for j in i.find_all("div"):
        for k in j.find_all("a", href = True):
            links_with_text.append(k["href"])

for i in bloque2:
    for j in i.find_all("a", href=True):
        if j.text:
            links_with_text.append(j["href"])

# %%
nombres = list()
marca = list()
modelo =list()
almacenamiento = list()
ram = list()
procesador = list()
precios = list()
codigos = list()

# %%
for i in range(len(links_with_text)):
    maux = 0
    moaux = 0
    almaux = 0
    proaux = 0
    ramaux = 0
    urlaux = "https://www.pcfactory.cl"+links_with_text[i]    
    responseaux = requests.get(urlaux)
    dataaux = responseaux.text
    soupaux = BeautifulSoup(dataaux,"html.parser")
    bloqueaux = soupaux.find("div",{"class":"lista-contenido-ficha"})
    bloqueprecio = soupaux.find("div",{"class":"price-xl color-gray-1"})
    precios.append(bloqueprecio.text)
    if(bloqueaux == None):
        bloqueaux = soupaux.find("div",{"class":"cfp_"})
    aux = bloqueaux.find_all("ul")
    if(len(aux)==1):
        for i in aux:
            caracteristicas = i.find_all("li")

        for i in range(len(caracteristicas)):
            caracteristicas[i] = caracteristicas[i].text

        for i in caracteristicas:
            if(i.find("Marca")!=-1):
                maux = maux + 1
                nombre_marca = i
            if(i.find("Modelo")!=-1):
                moaux = moaux + 1
                nombre_modelo = i
            if(i.find("Almacenamiento")!=-1):
                almaux = almaux + 1
                nombre_almacenamiento = i
            if(i.find("RAM:")!=-1 or i.find("Memoria:")!=-1 or i.find("Memoria Total:")!=-1):
                ramaux = ramaux + 1
                nombre_ram = i
            if(i.find("Procesador:")!=-1):
                proaux = proaux + 1
                nombre_procesador = i

        if(maux >= 1):
            marca.append(nombre_marca)
        elif(maux == 0):
            marca.append("Marca no encontrada")
        if(moaux >= 1):
            modelo.append(nombre_modelo)
        elif(moaux == 0):
            modelo.append("Modelo no encontrado")
        if(almaux >= 1):
            almacenamiento.append(nombre_almacenamiento)
        elif (almaux == 0 ):
            almacenamiento.append("Almacenamiento no encontrado")
        if(ramaux >= 1):
            ram.append(nombre_ram)
        elif(ramaux == 0):
            ram.append("Memoria ram no encontrada")
        if(proaux >= 1):
            procesador.append(nombre_procesador)
        elif(proaux == 0):
            procesador.append("Procesador no encontrado")

    if(len(aux)>=2):
        aux2 = aux[0]
        caracteristicas = aux2.find_all("li")

        for i in range(len(caracteristicas)):
            caracteristicas[i] = caracteristicas[i].text

        for i in caracteristicas:
            if(i.find("Marca")!=-1):
                maux = maux + 1
                nombre_marca = i
            if(i.find("Modelo")!=-1):
                moaux = moaux + 1
                nombre_modelo = i
            if(i.find("Almacenamiento")!=-1):
                almaux = almaux + 1
                nombre_almacenamiento = i
            if(i.find("RAM:")!=-1 or i.find("Memoria:")!=-1 or i.find("Memoria Total:")!=-1):
                ramaux = ramaux + 1
                nombre_ram = i
            if(i.find("Procesador:")!=-1):
                proaux = proaux + 1
                nombre_procesador = i

        if(maux >= 1):
            marca.append(nombre_marca)
        elif(maux == 0):
            marca.append("Marca no encontrada")
        if(moaux >= 1):
            modelo.append(nombre_modelo)
        elif(moaux == 0):
            modelo.append("Modelo no encontrado")
        if(almaux >= 1):
            almacenamiento.append(nombre_almacenamiento)
        elif (almaux == 0 ):
            almacenamiento.append("Almacenamiento no encontrado")
        if(ramaux >= 1):
            ram.append(nombre_ram)
        elif(ramaux == 0):
            ram.append("Memoria ram no encontrada")
        if(proaux >= 1):
            procesador.append(nombre_procesador)
        elif(proaux == 0):
            procesador.append("Procesador no encontrado")

# %%
for i in range(len(almacenamiento)):
    almacenamiento[i] = almacenamiento[i].replace("\xa0", " ")
    almacenamiento[i] = almacenamiento[i].replace("Almacenamiento:", "")
    almacenamiento[i] = almacenamiento[i].lstrip()

for i in range(len(marca)):
    marca[i] = marca[i].replace("\xa0"," ")
    marca[i] = marca[i].replace("Marca:","")
    marca[i] = marca[i].lstrip()

for i in range(len(modelo)):
    modelo[i] = modelo[i].replace("\xa0", " ")
    modelo[i] = modelo[i].replace("Modelo:", "")
    modelo[i] = modelo[i].lstrip()

for i in range(len(ram)):
    ram[i] = ram[i].replace("\xa0", " ")
    ram[i] = ram[i].replace("Memoria RAM:", "")
    ram[i] = ram[i].replace("Memoria:", "")
    ram[i] = ram[i].replace("Memoria Total:", "")
    ram[i] = ram[i].lstrip()

for i in range(len(procesador)):
    procesador[i] = procesador[i].replace("\xa0"," ")
    procesador[i] = procesador[i].replace("Procesador:","")
    procesador[i] = procesador[i].lstrip()

for i in range(len(precios)):
    precios[i] = precios[i].replace(" ","")
    precios[i] = precios[i].replace("$","")
    precios[i] = precios[i].replace(".","")

for i in range(len(marca)):
    nombres.append(marca[i] + " " + modelo[i])

# %%
bloque_codigo1 = soup.find_all("p",{"class":"link color-dark"})
bloque_codigo2 = soup2.find_all("p",{"class":"link color-dark"})
for i in bloque_codigo1:
    codigo = i.find("span")
    codigos.append(codigo.text)
    
for i in bloque_codigo2:
    codigo = i.find("span")
    codigos.append(codigo.text)

# %%
df = pd.DataFrame(columns=['Nombre','Código' ,'Almacenamiento', 'Procesador', 'Memoria Ram', 'Precio'])

# %%
for i in range(len(links_with_text)):
    df = df.append({'Nombre': nombres[i],'Código':codigos[i] ,'Almacenamiento':almacenamiento[i],'Procesador':procesador[i], 'Memoria Ram':ram[i], "Precio":precios[i]},ignore_index=True)

# %%
df['Nombre'] = df['Nombre'].astype(str)
df['Almacenamiento'] = df['Almacenamiento'].astype('str')
df['Código'] = df['Código'].astype(str)
df['Procesador'] = df['Procesador'].astype(str)
df['Memoria Ram'] = df['Memoria Ram'].astype(str)
df['Precio'] = df['Precio'].astype(int)

# %%
df.to_csv('PcFactory_Oficial.csv')

# %%
df.to_excel(r'C:\Users\ramir\Escritorio\Pc_factory.xlsx', index = False, header=True)

# %%
df
# Out:
#                           Nombre Código  \
# 0                  HP Chromebook  42710
# 1                      HP 240 G7  38020
# 2             Asus X515MA-BR288T  41517
# 3                      HP 250 G8  41940
# 4                   HP HP 348 G7  42392
# 5            Asus X412FA-EB1257T  40077
# 6                      HP 240 G7  38857
# 7                 HP 14-ck2091la  39522
# 8               HP Pavilion x360  42691
# 9   Asus Aspire 3 A314-22-R522-1  42823
# 10                HP 14-dq2026la  43015
# 11                HP 15-ef1018la  41355
# 12  Asus Aspire 3 A314-22-R56E-1  43016
# 13  Acer Aspire 5 A515-54-34VM-2  42435
# 14                HP 14-dy0501la  43061
# 15          Huawei Matebook D 14  42359
# 16                HP 15-ec1026la  37289
# 17  Acer Nitro 5 AN515-54-59UV-7  38217
# 18            Asus X571GT-BQ930T  41518
# 19       Asus ideapad S540-13IML  42015
# 20       Asus ideapad S540-13IML  42528
# 21  Acer Nitro 5 AN515-55-56P2-2  42048
# 22                HP 15-dk1028la  42347
# 23            Asus D433IA-EB934R  43186
# 24  HP Pavilion Aero 13-be0501la  42281
# 25                HP 15-eh0011la  43062
# 26           Lenovo ThinkPad L14  42019
# 27              Lenovo ThinkBook  42192
# 28                HP 13-ba1123la  39513
# 29           Lenovo Ideapad s540  40025
# 30             Apple Macbook Air  40893
# 31             Apple Macbook Air  41980
# 32             Apple Macbook Air  40890
# 33    Acer Swift 3 SF313-53-74FL  40965
# 34           HP OMEN 15-en0002la  40501
# 35          Asus UX435EG-AI094TS  37724
# 36           Asus FX516PC-HN021T  41903
# 37             Apple Macbook Air  40894
# 38             Apple Macbook Air  42014
# 39             Apple Macbook Air  40892
# 40              Huawei Mate Xpro  42708
# 41             Apple Macbook Pro  41175
# 42             Apple Macbook Pro  42282
# 43             Asus ROG Flow X13  41570
# 44                HP 13-ba1124la  39511
# 45           Lenovo ThinkPad X13  41852
# 46          Lenovo Yoga 9 14ITL5  40625
# 47             Apple Macbook Pro  41174
#
#                                        Almacenamiento  \
# 0                                           32GB eMMC
# 1                            SATA de 500 GB, 5400 rpm
# 2                         500GB SATA 5400RPM 2.5" HDD
# 3                     1TB Disco duro SATA de 5400 RPM
# 4                                    HDD 1 TB 5400RPM
# 5                     256GB SSD / M.2 NVMe™ PCIe® 3.0
# 6                             SATA de 1 TB y 5400 rpm
# 7                                 128GB SSD SATA M.2
# 8                        SSD PCIe® NVMe™ M.2 de 256GB
# 9                               256GB SSD PCI Express
# 10  Unidad de estado sólido Intel® PCIe® NVMe™ M.2...
# 11                          256GB SSD PCIe® NVMe™ M.2
# 12                              256GB SSD PCI Express
# 13                              512GB SSD PCI Express
# 14  Unidad de estado sólido PCIe® NVMe™ M.2 de 256 GB
# 15                            SSD NVMe PCIe de 512 GB
# 16                         256GB SSD PCIe®  NVMe™ M.2
# 17              1TB HDD 5400rpm 2.5" SATA + 128GB SSD
# 18                      512GB M.2 NVMe™ PCIe® 3.0 SSD
# 19                 512GB SSD M.2 2280 PCIe 3.0x4 NVMe
# 20                 512GB SSD M.2 2280 PCIe 3.0x4 NVMe
# 21                              512GB SSD PCI Express
# 22          256GB SSD / Unidad de estado sólido Intel
# 23                      512GB M.2 NVMe™ PCIe® 3.0 SSD
# 24  Unidad de estado sólido M.2 PCIe® NVMe™ de 512 GB
# 25  Unidad de estado sólido M.2 PCIe® NVMe™ de 512 GB
# 26                 256GB SSD M.2 2242 PCIe 3.0x2 NVMe
# 27                       SSD M.2 2242 de hasta 512 GB
# 28  Unidad de estado sólido PCIe® NVMe™ M.2 de 256...
# 29                 512GB SSD M.2 2280 PCIe 3.0x4 NVMe
# 30                                      SSD de 256 GB
# 31                                      SSD de 256 GB
# 32                                      SSD de 256 GB
# 33                              512GB SSD PCI Express
# 34                          512GB SSD M.2 PCIe® NVMe™
# 35                          512GB SSD M.2 NVMe™ PCIe®
# 36                      512GB M.2 NVMe™ PCIe® 3.0 SSD
# 37                                      SSD de 512 GB
# 38                                      SSD de 512 GB
# 39                                      SSD de 512 GB
# 40                            SSD NVMe PCIe de 512 GB
# 41                                      SSD de 256 GB
# 42                                      SSD de 256 GB
# 43                 512GB M.2 2230 NVMe™ PCIe® 3.0 SSD
# 44  512GB SSD / Unidad de estado sólido Intel® PCI...
# 45                 512GB SSD M.2 2280 PCIe 3.0x4 NVMe
# 46                                   1TB SSD M.2 NVME
# 47                                      SSD de 512 GB
#
#                                            Procesador  \
# 0     AMD® A4-9120, 1,6GHz hasta 2,4GHz (1M Caché L2)
# 1   Intel® Celeron® N4020, 1,1 GHz hasta 2,8 GHz (...
# 2   Intel® Celeron® N4020, 1.1GHz hasta 2.8GHz (4M...
# 3   Intel® Core™ 3-1005G1, 1,2GHz hasta 3,4GHz (4M...
# 4   Intel® Core™ i3-10110U, 2,10GHz hasta 4,10GHz ...
# 5   Intel® Pentium® Gold 5405U, frecuencia básica ...
# 6   Intel® Core™ i3-1005G1, 1,2GHz hasta 3,4GHz (4...
# 7   Intel® Core™ i3-10110U, 2,1GHz hasta 4,1GHz (4...
# 8   Intel® Pentium Gold 7505, hasta 3,5GHz (4MB Ca...
# 9   AMD Athlon™ 3050U, 2.30GHz hasta 3.20GHz (4MB ...
# 10  Intel® Core™ i3-1115G4, hasta 4,1GHz (6MB cach...
# 11  AMD Ryzen™ 5 4500U, 2,3GHz hasta 4,0GHz (8MB C...
# 12  AMD Ryzen™ 3 3250U, 2.60GHz hasta 3.50GHz (4MB...
# 13  Intel® Core™ i3 10110U, 2.10GHz hasta 4.10GHz ...
# 14  Intel® Core™ i3-1125G4, hasta 3,70GHz (8MB caché)
# 15  Intel® Core™ i5-10210U, 1,60GHz hasta 4,20GHz ...
# 16  AMD Ryzen™ 5 4600H, 3.0GHz hasta 4,0 GHz (3MB ...
# 17  Intel® Core™ i5-9300H, 2.40GHz hasta 4.10GHz (...
# 18  Intel® Core™ i5-9300H, 2.4GHz hasta 4.1GHz (8M...
# 19  Intel® Core™ i5-10210U, 1.6GHz hasta 4.2GHz (6...
# 20  Intel® Core™ i5-10210U, 1.6GHz hasta 4.2GHz (6...
# 21  Intel® Core™ i5-10300H, 2.50GHz hasta 4.50GHz ...
# 22  Intel® Core™ i5-10300H, 2,5 GHz hasta 4,5GHz (...
# 23  AMD Ryzen™ 7 4700U, 2.0GHz hasta 4.1GHz (8MB C...
# 24  AMD Ryzen™ 5 5600U, 2,3 GHz hasta 4,2GHz (16MB...
# 25  AMD Ryzen™ 7 4700U, 2,0GHz hasta 4,1GHz (8MB c...
# 26  Intel® Core™ i5-10210U, 1,60GHz hasta 4.2GHz (...
# 27  Intel® Core™ i7-10510U, 1,8GHz hasta 4,9GHz (8...
# 28  Intel® Core™ i5-1135G7,  hasta 4.2 GHz (8M Caché)
# 29    Intel Core i7-10510U, desde 1.8GHz hasta 4.9GHz
# 30  M1 de Apple 8 núcleos con 4 núcleos de rendimi...
# 31  M1 de Apple 8 núcleos con 4 núcleos de rendimi...
# 32  M1 de Apple 8 núcleos con 4 núcleos de rendimi...
# 33      Intel® Core™ i7-1165G7, 2.80GHz hasta 4.70GHz
# 34  AMD Ryzen™ 7 4800H, 2,9GHz hasta 4,3GHz (4MB c...
# 35  Intel® Core™ i5-1135G7, 2.4 GHz hasta 4.2GHz (...
# 36  Intel® Core™ i7-11370H, 3.3GHz hasta  4.8GHz (...
# 37  M1 de Apple 8 núcleos con 4 núcleos de rendimi...
# 38  M1 de Apple 8 núcleos con 4 núcleos de rendimi...
# 39  M1 de Apple 8 núcleos con 4 núcleos de rendimi...
# 40  Intel® Core™ i5-1135G7, hasta 4,20GHz (8MB Caché)
# 41  M1 de Apple 8 núcleos con 4 núcleos de rendimi...
# 42  M1 de Apple 8 núcleos con 4 núcleos de rendimi...
# 43  AMD Ryzen™ 7 5800HS, 3.0GHz hasta 4.3GHz (16M ...
# 44  Intel® Core™ i7-1165G7,  hasta 4.7 GHz (12M Ca...
# 45   Intel® Core™ i5-10210U, hasta 4.2GHz (6MB Caché)
# 46            Intel® Core™ i5 -1135G7 hasta 4,20 GHz.
# 47  M1 de Apple 8 núcleos con 4 núcleos de rendimi...
#
#                                           Memoria Ram   Precio
# 0   4 GB (1x4GB) DDR4 2666Mhz (Máx. 32GB de Memori...   237090
# 1   4GB SDRAM DDR4-2400Mhz (1x4GB)(Máx. 8GB de Mem...   319590
# 2   4GB DDR4 SO-DIMM (Máx. 8GB de Memoria RAM) 1X ...   349990
# 3   4GB RAM DDR4-2666MHz (1x4GB)(Máx. 16GB de Memo...   391790
# 4   4GB DDR4 2666Mhz (Máx. 16 GB de Memoria RAM) 2...   391790
# 5             4GB DDR4 on board (Máx memoria RAM 4GB)   412390
# 6   4 GB de SDRAM DDR4-2666 (1x4GB) (Máx. 16GB de ...   432990
# 7   4GB SDRAM DDR4-2666Mhz (1x 4GB) (máximo memori...   432990
# 8   4 GB DDR4-3200MHz (1x4GB) (Máx.16 GB de Memori...   453590
# 9   12GB DDR4 SDRAM 2400/2666/3200Mhz (4GB On Boar...   453590
# 10  4GB RAM DDR4-3200MHz (1x 4GB) + 16GB Intel® Op...   453590
# 11  8 GB de SDRAM DDR4-2666 (1x8GB) (Máx. 16 GB de...   525790
# 12  12GB (4GB On Board + 1 Slot)(Máx. 12GB de Memo...   549990
# 13  12GB DDR4 SDRAM 2400/2666/3200 (4GB On Board +...   599990
# 14  8 GB de RAM DDR4-3200 MHz (2x4GB)(Máx. 16GB de...   639190
# 15                                 8GB DDR4 2400 mhz    721690
# 16  8GB SDRAM DDR4 3200Mhz (Máx. 16GB de Memoria R...   731990
# 17   8GB DDR4 SDRAM (Máx. 32GB de Memoria RAM) 2 Slot   752590
# 18  8GB DDR4 (4GB DDR4 on board + 4GB DDR4 SO-DIMM...   783490
# 19  8GB Soldered DDR4-2666Mhz (Máx.16 GB de Memori...   804090
# 20  8GB Soldered DDR4-2666Mhz (Máx.16 GB de Memori...   804090
# 21  16GB DDR4 SODIMM 2400/2666/3200Mhz (Máx. 32GB ...   824790
# 22  8GB SDRAM DDR4-2933Mhz (1x8GB) + 16GB Intel Op...   824790
# 23  16GB DDR4 2666 MHz (on board)(Máx.16 GB de Mem...   845390
# 24  8GB RAM DDR4-3200 MHz (integrada)(Máx. GB de M...   849990
# 25  16 GB de SDRAM DDR4-3200 (2x8GB)(Máx. 16GB de ...   879990
# 26  8GB SO-DIMM DDR4-2666Mhz (Máx. 64GB de Memoria...   899990
# 27  8GB DDR4-2666Mhz (Soldered) (Máx. 40GB de Memo...   919990
# 28  8GB de SDRAM DDR4-2933 (incorporada) (8GB Máx....   927790
# 29       16GB DDR4 2666MHz ( Máx. RAM soportada 16GB)   948490
# 30                                               8 GB  1010290
# 31                                               8 GB  1010290
# 32                                               8 GB  1010290
# 33                               16GB LPDDR4X 4266MHz  1129990
# 34  16GB SDRAM DDR4-3200Mhz (2x8GB) (Máx. 16GB de ...  1185590
# 35  8GB LPDDR4X (on board) + 32GB de memoria Intel...  1199990
# 36  8GB DDR4 3200Mhz (on board)(Máx. 32GB de Memor...  1206190
# 37                                               8 GB  1237090
# 38                                               8 GB  1237090
# 39                                               8 GB  1237090
# 40     16GB LPDDR4x (Máx. 16GB de Memoria RAM) 1 Slot  1237090
# 41                                               8 GB  1288690
# 42                                               8 GB  1288690
# 43  16GB LPDDR4X (on board)(Máx. 16GB de Memoria R...  1340190
# 44  8GB SDRAM DDR4 2933Mhz + 32GB Intel® Optane™(8...  1340190
# 45  16GB DDR4-2666Mhz (Máx. 16 GB de Memoria RAM s...  1349990
# 46  16GB Soldered LPDDR4x-4266(Memoria soldada al ...  1499990
# 47                                               8 GB  1546390
